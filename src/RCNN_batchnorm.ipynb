# %%
import keras
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, \
    Flatten, Lambda, LSTM, RepeatVector, TimeDistributed, Reshape, \
    Conv2D, MaxPooling2D, BatchNormalization, ConvLSTM2D, Bidirectional
import numpy as np
import h5py
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import scale

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import json
# Out:
# /home/weihangzhang/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# # models
# from keras.applications.inception_v3 import InceptionV3
# from keras.applications.vgg16 import VGG16
# from keras.applications.resnet50 import ResNet50

# %%
data = h5py.File("./data_sample.hdf5", "r")
print("data keys: " + str(list(data.keys())))
# Out:
# data keys: ['images', 'labels', 'observation_days']

# %%
images = data["images"][:]
print("image shape: (sample, x_size, y_size, epoch) = " + str(images.shape))
labels = data["labels"][:]
# Out:
# image shape: (sample, x_size, y_size, epoch) = (72000, 21, 21, 48)

# %%
def scale_images(images):
    t_images = np.transpose(images, (0,3,1,2))
    rt_images = t_images.reshape(72000*48, 21, 21)
    max_per_img = np.max(rt_images.reshape(-1, 21*21), axis=1, keepdims=1)
    scaled_images = rt_images.reshape(-1, 21*21) / max_per_img
    scaled_images = scaled_images.reshape(-1, 21, 21).reshape(-1, 48, 21, 21)
    return scaled_images

# %%
def txt2digit(labels):
    dic = {'Asteroids':0, 'Constant':1, 'EmptyLigh':2, 'M33Cephei':3, 'RRLyrae':4, 'Supernova':5}
    labels_digit = np.array([dic[i] for i in labels])
    return labels_digit

# %%
def build_dataset(images, labels, seq2seq=False):
    
    train_indices = np.random.choice(np.arange(images.shape[0]), int( 0.7 * images.shape[0]))
    val_indices = list(set(np.arange(images.shape[0])) - set(train_indices))
    
    x = np.transpose(images, (0, 3, 1, 2))
    x = np.expand_dims(x, len(x.shape))
    y = to_categorical(txt2digit(labels))
    
    if seq2seq:
        y = np.repeat(y, 48).reshape(-1, 48, 6)
    
    return x, y

# %%
x, y = build_dataset(images, labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=209, stratify=y)

# %%
x_train.shape
# Out:
# (57600, 48, 21, 21, 1)

# %%
def init_model3(cnn_input_dim=21, cnn_output_dim=128, cnn_dropout=0.5,
               rnn_hidden_dim=128, rnn_output_dim=64, num_classes=6, rnn_dropout=0.5, timestep=48,
               bidir_mode='concat'):
    
    input_shape = (timestep, cnn_input_dim, cnn_input_dim, 1, )
    
    model = Sequential()
    
    model.add(TimeDistributed(Conv2D(48, (4,4), \
                     padding='same', activation='relu', kernel_initializer='uniform'), input_shape=input_shape))
#     model.add(TimeDistributed(BatchNormalization()))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))
    
    model.add(TimeDistributed(Conv2D(24, (3,3), padding='same', activation='relu', kernel_initializer='uniform')))
#     model.add(TimeDistributed(BatchNormalization()))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))

    model.add(TimeDistributed(Conv2D(12, (3,3), padding='same', activation='relu', kernel_initializer='uniform')))
    model.add(TimeDistributed(BatchNormalization(momentum=0.3)))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))
    
    model.add(TimeDistributed(Flatten()))

    model.add(TimeDistributed(Dense(128, activation='relu')))
    model.add(Dropout(0.25))
    
    model.add(LSTM(rnn_hidden_dim, dropout=rnn_dropout, return_sequences=True))
    model.add(LSTM(rnn_hidden_dim, dropout=rnn_dropout))
    
    model.add(Dense(6, activation='softmax'))
    
    return model

# %%
opt = keras.optimizers.Adam(lr=5*1e-4)
model3 = init_model3(bidir_mode='ave')
model3.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_71 (TimeDis (None, 48, 21, 21, 48)    816
# _________________________________________________________________
# time_distributed_72 (TimeDis (None, 48, 19, 19, 48)    0
# _________________________________________________________________
# time_distributed_73 (TimeDis (None, 48, 19, 19, 24)    10392
# _________________________________________________________________
# time_distributed_74 (TimeDis (None, 48, 17, 17, 24)    0
# _________________________________________________________________
# time_distributed_75 (TimeDis (None, 48, 17, 17, 12)    2604
# _________________________________________________________________
# time_distributed_76 (TimeDis (None, 48, 17, 17, 12)    48
# _________________________________________________________________
# time_distributed_77 (TimeDis (None, 48, 15, 15, 12)    0
# _________________________________________________________________
# time_distributed_78 (TimeDis (None, 48, 2700)          0
# _________________________________________________________________
# time_distributed_79 (TimeDis (None, 48, 128)           345728
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 48, 128)           0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 48, 128)           131584
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 623,530
# Trainable params: 623,506
# Non-trainable params: 24
# _________________________________________________________________

# %%
batch_size = 100
epochs = 100

checkpoint = keras.callbacks.ModelCheckpoint('best_checkpoint/batchnorm_best.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')
model3_fit = model3.fit(x_train[::4], y_train[::4],
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              callbacks=[checkpoint],
              shuffle=True)
# Out:
# Train on 14400 samples, validate on 14400 samples
# Epoch 1/100
# 14400/14400 [==============================] - 46s 3ms/step - loss: 1.4938 - acc: 0.3337 - val_loss: 3.7355 - val_acc: 0.1837
#
# Epoch 00001: val_acc improved from -inf to 0.18375, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 2/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.1833 - acc: 0.4312 - val_loss: 4.4196 - val_acc: 0.1877
#
# Epoch 00002: val_acc improved from 0.18375 to 0.18771, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 3/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.1359 - acc: 0.4391 - val_loss: 1.0375 - val_acc: 0.4617
#
# Epoch 00003: val_acc improved from 0.18771 to 0.46167, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 4/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.0694 - acc: 0.4604 - val_loss: 0.9941 - val_acc: 0.4926
#
# Epoch 00004: val_acc improved from 0.46167 to 0.49264, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 5/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.0118 - acc: 0.4892 - val_loss: 1.0081 - val_acc: 0.4989
#
# Epoch 00005: val_acc improved from 0.49264 to 0.49889, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 6/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.0257 - acc: 0.4865 - val_loss: 1.0089 - val_acc: 0.5318
#
# Epoch 00006: val_acc improved from 0.49889 to 0.53181, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 7/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.9498 - acc: 0.5209 - val_loss: 0.9161 - val_acc: 0.5390
#
# Epoch 00007: val_acc improved from 0.53181 to 0.53903, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 8/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.3591 - acc: 0.4124 - val_loss: 3.1259 - val_acc: 0.1828
#
# Epoch 00008: val_acc did not improve from 0.53903
# Epoch 9/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 1.0915 - acc: 0.4731 - val_loss: 1.0501 - val_acc: 0.4771
#
# Epoch 00009: val_acc did not improve from 0.53903
# Epoch 10/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.9815 - acc: 0.5114 - val_loss: 0.9518 - val_acc: 0.5396
#
# Epoch 00010: val_acc improved from 0.53903 to 0.53958, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 11/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.9543 - acc: 0.5210 - val_loss: 0.9562 - val_acc: 0.5194
#
# Epoch 00011: val_acc did not improve from 0.53958
# Epoch 12/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.9177 - acc: 0.5286 - val_loss: 0.8627 - val_acc: 0.5606
#
# Epoch 00012: val_acc improved from 0.53958 to 0.56062, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 13/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.9365 - acc: 0.5329 - val_loss: 0.8837 - val_acc: 0.5512
#
# Epoch 00013: val_acc did not improve from 0.56062
# Epoch 14/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8879 - acc: 0.5449 - val_loss: 0.8328 - val_acc: 0.5676
#
# Epoch 00014: val_acc improved from 0.56062 to 0.56764, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 15/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8514 - acc: 0.5617 - val_loss: 2.9987 - val_acc: 0.3006
#
# Epoch 00015: val_acc did not improve from 0.56764
# Epoch 16/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8418 - acc: 0.5647 - val_loss: 0.8375 - val_acc: 0.5729
#
# Epoch 00016: val_acc improved from 0.56764 to 0.57292, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 17/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8333 - acc: 0.5689 - val_loss: 0.8097 - val_acc: 0.5741
#
# Epoch 00017: val_acc improved from 0.57292 to 0.57410, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 18/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.9051 - acc: 0.5428 - val_loss: 0.8193 - val_acc: 0.5700
#
# Epoch 00018: val_acc did not improve from 0.57410
# Epoch 19/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8380 - acc: 0.5659 - val_loss: 0.8107 - val_acc: 0.5759
#
# Epoch 00019: val_acc improved from 0.57410 to 0.57590, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 20/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8256 - acc: 0.5658 - val_loss: 0.8344 - val_acc: 0.5723
#
# Epoch 00020: val_acc did not improve from 0.57590
# Epoch 21/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.8152 - acc: 0.5714 - val_loss: 0.8070 - val_acc: 0.5766
#
# Epoch 00021: val_acc improved from 0.57590 to 0.57660, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 22/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8135 - acc: 0.5696 - val_loss: 0.7930 - val_acc: 0.5876
#
# Epoch 00022: val_acc improved from 0.57660 to 0.58764, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 23/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8059 - acc: 0.5751 - val_loss: 0.7996 - val_acc: 0.5794
#
# Epoch 00023: val_acc did not improve from 0.58764
# Epoch 24/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7898 - acc: 0.5812 - val_loss: 0.7790 - val_acc: 0.5883
#
# Epoch 00024: val_acc improved from 0.58764 to 0.58833, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 25/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7925 - acc: 0.5794 - val_loss: 0.7800 - val_acc: 0.5843
#
# Epoch 00025: val_acc did not improve from 0.58833
# Epoch 26/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8078 - acc: 0.5762 - val_loss: 0.7830 - val_acc: 0.5883
#
# Epoch 00026: val_acc did not improve from 0.58833
# Epoch 27/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7880 - acc: 0.5826 - val_loss: 0.7623 - val_acc: 0.5921
#
# Epoch 00027: val_acc improved from 0.58833 to 0.59208, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 28/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.7794 - acc: 0.5890 - val_loss: 0.7773 - val_acc: 0.5877
#
# Epoch 00028: val_acc did not improve from 0.59208
# Epoch 29/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7719 - acc: 0.5887 - val_loss: 0.7586 - val_acc: 0.5934
#
# Epoch 00029: val_acc improved from 0.59208 to 0.59340, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 30/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.7858 - acc: 0.5831 - val_loss: 0.7903 - val_acc: 0.5799
#
# Epoch 00030: val_acc did not improve from 0.59340
# Epoch 31/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7739 - acc: 0.5879 - val_loss: 0.7638 - val_acc: 0.5906
#
# Epoch 00031: val_acc did not improve from 0.59340
# Epoch 32/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7635 - acc: 0.5940 - val_loss: 0.7584 - val_acc: 0.5979
#
# Epoch 00032: val_acc improved from 0.59340 to 0.59792, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 33/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.7639 - acc: 0.5955 - val_loss: 0.7594 - val_acc: 0.6142
#
# Epoch 00033: val_acc improved from 0.59792 to 0.61417, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 34/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.7671 - acc: 0.5928 - val_loss: 0.7557 - val_acc: 0.5935
#
# Epoch 00034: val_acc did not improve from 0.61417
# Epoch 35/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7739 - acc: 0.5862 - val_loss: 0.7621 - val_acc: 0.6093
#
# Epoch 00035: val_acc did not improve from 0.61417
# Epoch 36/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.7602 - acc: 0.5981 - val_loss: 0.7581 - val_acc: 0.5933
#
# Epoch 00036: val_acc did not improve from 0.61417
# Epoch 37/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7590 - acc: 0.5951 - val_loss: 0.7468 - val_acc: 0.6238
#
# Epoch 00037: val_acc improved from 0.61417 to 0.62382, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 38/100
# 14400/14400 [==============================] - 40s 3ms/step - loss: 0.7527 - acc: 0.6001 - val_loss: 0.7484 - val_acc: 0.6022
#
# Epoch 00038: val_acc did not improve from 0.62382
# Epoch 39/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7542 - acc: 0.6033 - val_loss: 0.7383 - val_acc: 0.6231
#
# Epoch 00039: val_acc did not improve from 0.62382
# Epoch 40/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7508 - acc: 0.6031 - val_loss: 1.7769 - val_acc: 0.3824
#
# Epoch 00040: val_acc did not improve from 0.62382
# Epoch 41/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7645 - acc: 0.6044 - val_loss: 0.7369 - val_acc: 0.6081
#
# Epoch 00041: val_acc did not improve from 0.62382
# Epoch 42/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7465 - acc: 0.6137 - val_loss: 0.7425 - val_acc: 0.6327
#
# Epoch 00042: val_acc improved from 0.62382 to 0.63271, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 43/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7404 - acc: 0.6167 - val_loss: 0.7318 - val_acc: 0.6338
#
# Epoch 00043: val_acc improved from 0.63271 to 0.63375, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 44/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7385 - acc: 0.6197 - val_loss: 0.7445 - val_acc: 0.6253
#
# Epoch 00044: val_acc did not improve from 0.63375
# Epoch 45/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.9053 - acc: 0.5666 - val_loss: 0.7912 - val_acc: 0.5959
#
# Epoch 00045: val_acc did not improve from 0.63375
# Epoch 46/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.8126 - acc: 0.5930 - val_loss: 0.8731 - val_acc: 0.6036
#
# Epoch 00046: val_acc did not improve from 0.63375
# Epoch 47/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7889 - acc: 0.6027 - val_loss: 0.7358 - val_acc: 0.6444
#
# Epoch 00047: val_acc improved from 0.63375 to 0.64444, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 48/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7498 - acc: 0.6216 - val_loss: 0.7744 - val_acc: 0.6248
#
# Epoch 00048: val_acc did not improve from 0.64444
# Epoch 49/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7488 - acc: 0.6303 - val_loss: 0.7783 - val_acc: 0.6076
#
# Epoch 00049: val_acc did not improve from 0.64444
# Epoch 50/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7199 - acc: 0.6460 - val_loss: 0.6905 - val_acc: 0.6792
#
# Epoch 00050: val_acc improved from 0.64444 to 0.67924, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 51/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7348 - acc: 0.6447 - val_loss: 0.6709 - val_acc: 0.6794
#
# Epoch 00051: val_acc improved from 0.67924 to 0.67938, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 52/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.7146 - acc: 0.6453 - val_loss: 0.6752 - val_acc: 0.6638
#
# Epoch 00052: val_acc did not improve from 0.67938
# Epoch 53/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6961 - acc: 0.6578 - val_loss: 0.6821 - val_acc: 0.6809
#
# Epoch 00053: val_acc improved from 0.67938 to 0.68090, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 54/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6725 - acc: 0.6764 - val_loss: 0.6291 - val_acc: 0.7113
#
# Epoch 00054: val_acc improved from 0.68090 to 0.71125, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 55/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.6658 - acc: 0.6789 - val_loss: 0.6603 - val_acc: 0.6818
#
# Epoch 00055: val_acc did not improve from 0.71125
# Epoch 56/100
# 14400/14400 [==============================] - 40s 3ms/step - loss: 0.6726 - acc: 0.6774 - val_loss: 0.7093 - val_acc: 0.6841
#
# Epoch 00056: val_acc did not improve from 0.71125
# Epoch 57/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6954 - acc: 0.6646 - val_loss: 0.6699 - val_acc: 0.6885
#
# Epoch 00057: val_acc did not improve from 0.71125
# Epoch 58/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6527 - acc: 0.6850 - val_loss: 0.6096 - val_acc: 0.7199
#
# Epoch 00058: val_acc improved from 0.71125 to 0.71993, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 59/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6458 - acc: 0.6881 - val_loss: 0.6600 - val_acc: 0.6891
#
# Epoch 00059: val_acc did not improve from 0.71993
# Epoch 60/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.6304 - acc: 0.7003 - val_loss: 0.5724 - val_acc: 0.7351
#
# Epoch 00060: val_acc improved from 0.71993 to 0.73514, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 61/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6193 - acc: 0.7048 - val_loss: 0.6003 - val_acc: 0.7094
#
# Epoch 00061: val_acc did not improve from 0.73514
# Epoch 62/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6121 - acc: 0.7098 - val_loss: 0.5499 - val_acc: 0.7442
#
# Epoch 00062: val_acc improved from 0.73514 to 0.74417, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 63/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6052 - acc: 0.7067 - val_loss: 0.5389 - val_acc: 0.7574
#
# Epoch 00063: val_acc improved from 0.74417 to 0.75736, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 64/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.6525 - acc: 0.6877 - val_loss: 0.5813 - val_acc: 0.7397
#
# Epoch 00064: val_acc did not improve from 0.75736
# Epoch 65/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5992 - acc: 0.7149 - val_loss: 0.5865 - val_acc: 0.7360
#
# Epoch 00065: val_acc did not improve from 0.75736
# Epoch 66/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.5844 - acc: 0.7207 - val_loss: 0.5374 - val_acc: 0.7531
#
# Epoch 00066: val_acc did not improve from 0.75736
# Epoch 67/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5784 - acc: 0.7276 - val_loss: 0.5863 - val_acc: 0.7229
#
# Epoch 00067: val_acc did not improve from 0.75736
# Epoch 68/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5749 - acc: 0.7274 - val_loss: 0.5677 - val_acc: 0.7449
#
# Epoch 00068: val_acc did not improve from 0.75736
# Epoch 69/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5750 - acc: 0.7256 - val_loss: 0.5607 - val_acc: 0.7384
#
# Epoch 00069: val_acc did not improve from 0.75736
# Epoch 70/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.5688 - acc: 0.7323 - val_loss: 0.5545 - val_acc: 0.7467
#
# Epoch 00070: val_acc did not improve from 0.75736
# Epoch 71/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.5588 - acc: 0.7382 - val_loss: 0.5280 - val_acc: 0.7596
#
# Epoch 00071: val_acc improved from 0.75736 to 0.75958, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 72/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.5577 - acc: 0.7349 - val_loss: 0.5547 - val_acc: 0.7452
#
# Epoch 00072: val_acc did not improve from 0.75958
# Epoch 73/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5973 - acc: 0.7181 - val_loss: 0.5664 - val_acc: 0.7448
#
# Epoch 00073: val_acc did not improve from 0.75958
# Epoch 74/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5579 - acc: 0.7354 - val_loss: 0.5109 - val_acc: 0.7661
#
# Epoch 00074: val_acc improved from 0.75958 to 0.76611, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 75/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5471 - acc: 0.7372 - val_loss: 0.5326 - val_acc: 0.7549
#
# Epoch 00075: val_acc did not improve from 0.76611
# Epoch 76/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5400 - acc: 0.7419 - val_loss: 0.5037 - val_acc: 0.7616
#
# Epoch 00076: val_acc did not improve from 0.76611
# Epoch 77/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5367 - acc: 0.7438 - val_loss: 0.5521 - val_acc: 0.7553
#
# Epoch 00077: val_acc did not improve from 0.76611
# Epoch 78/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5278 - acc: 0.7466 - val_loss: 0.5011 - val_acc: 0.7731
#
# Epoch 00078: val_acc improved from 0.76611 to 0.77306, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 79/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5310 - acc: 0.7503 - val_loss: 0.5286 - val_acc: 0.7657
#
# Epoch 00079: val_acc did not improve from 0.77306
# Epoch 80/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5368 - acc: 0.7453 - val_loss: 0.5251 - val_acc: 0.7592
#
# Epoch 00080: val_acc did not improve from 0.77306
# Epoch 81/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5253 - acc: 0.7525 - val_loss: 0.5571 - val_acc: 0.7616
#
# Epoch 00081: val_acc did not improve from 0.77306
# Epoch 82/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5179 - acc: 0.7551 - val_loss: 0.4814 - val_acc: 0.7862
#
# Epoch 00082: val_acc improved from 0.77306 to 0.78618, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 83/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5073 - acc: 0.7623 - val_loss: 0.5173 - val_acc: 0.7701
#
# Epoch 00083: val_acc did not improve from 0.78618
# Epoch 84/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5142 - acc: 0.7577 - val_loss: 0.5088 - val_acc: 0.7751
#
# Epoch 00084: val_acc did not improve from 0.78618
# Epoch 85/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5053 - acc: 0.7656 - val_loss: 0.4879 - val_acc: 0.7767
#
# Epoch 00085: val_acc did not improve from 0.78618
# Epoch 86/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5037 - acc: 0.7630 - val_loss: 0.4875 - val_acc: 0.7805
#
# Epoch 00086: val_acc did not improve from 0.78618
# Epoch 87/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4951 - acc: 0.7696 - val_loss: 0.4746 - val_acc: 0.7879
#
# Epoch 00087: val_acc improved from 0.78618 to 0.78792, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 88/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4955 - acc: 0.7692 - val_loss: 0.5106 - val_acc: 0.7701
#
# Epoch 00088: val_acc did not improve from 0.78792
# Epoch 89/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5010 - acc: 0.7662 - val_loss: 0.4746 - val_acc: 0.7832
#
# Epoch 00089: val_acc did not improve from 0.78792
# Epoch 90/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4949 - acc: 0.7677 - val_loss: 0.4689 - val_acc: 0.7937
#
# Epoch 00090: val_acc improved from 0.78792 to 0.79368, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 91/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5128 - acc: 0.7596 - val_loss: 0.5560 - val_acc: 0.7477
#
# Epoch 00091: val_acc did not improve from 0.79368
# Epoch 92/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.5260 - acc: 0.7601 - val_loss: 0.5043 - val_acc: 0.7807
#
# Epoch 00092: val_acc did not improve from 0.79368
# Epoch 93/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4890 - acc: 0.7740 - val_loss: 0.4938 - val_acc: 0.7813
#
# Epoch 00093: val_acc did not improve from 0.79368
# Epoch 94/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.4957 - acc: 0.7731 - val_loss: 0.4557 - val_acc: 0.7988
#
# Epoch 00094: val_acc improved from 0.79368 to 0.79882, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 95/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.4808 - acc: 0.7794 - val_loss: 0.4493 - val_acc: 0.8022
#
# Epoch 00095: val_acc improved from 0.79882 to 0.80222, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 96/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4745 - acc: 0.7808 - val_loss: 0.4615 - val_acc: 0.7945
#
# Epoch 00096: val_acc did not improve from 0.80222
# Epoch 97/100
# 14400/14400 [==============================] - 42s 3ms/step - loss: 0.4773 - acc: 0.7822 - val_loss: 0.4491 - val_acc: 0.8052
#
# Epoch 00097: val_acc improved from 0.80222 to 0.80521, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 98/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.4757 - acc: 0.7835 - val_loss: 0.4449 - val_acc: 0.8097
#
# Epoch 00098: val_acc improved from 0.80521 to 0.80965, saving model to best_checkpoint/batchnorm_best.hdf5
# Epoch 99/100
# 14400/14400 [==============================] - 41s 3ms/step - loss: 0.4705 - acc: 0.7857 - val_loss: 0.4526 - val_acc: 0.8078
#
# Epoch 00099: val_acc did not improve from 0.80965
# Epoch 100/100
# 14300/14400 [============================>.] - ETA: 0s - loss: 0.4640 - acc: 0.7903

# %%
with open('batch_norm_history.json', 'w') as f:
    json.dump(model3_fit.history, f)

# %%
plt.figure(figsize=(8,8 ))
plt.plot(range(len(model3_fit.history['acc'])),\
         model3_fit.history['acc'], label='Training set accuracy')
plt.plot(range(len(model3_fit.history['acc'])), \
         model3_fit.history['val_acc'], label='Testing set accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Load saved best model and visualize the confusion matrix

# %%
model = keras.models.load_model('saved_models/rcnn_simple_lstm_ep300.hdf5')

# %%
def compute_confusion_matrix(model, x, y):
    from sklearn.metrics import confusion_matrix
    pred = model.predict_classes(x)
    labels = y @ np.array([0,1,2,3,4,5]).T
    cm = confusion_matrix(labels, pred)
    return cm

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    plt.figure(figsize=(6,6))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    tick_marks = np.arange(len(classes))
    plt.grid(False)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = compute_confusion_matrix(model, x_test, y_test)
plot_confusion_matrix(cm, classes=['Asteroids', 'Constant', 'EmptyLigh', 'M33Cephei', 'RRLyrae', 'Supernova'])
# Out:
# Confusion matrix, without normalization
