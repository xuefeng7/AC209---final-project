# %%
import keras
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, \
    Flatten, Lambda, LSTM, RepeatVector, TimeDistributed, Reshape, \
    Conv2D, MaxPooling2D, BatchNormalization, ConvLSTM2D, Bidirectional
import numpy as np
import h5py
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import scale

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import json
# Out:
# /usr/share/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# # models
# from keras.applications.inception_v3 import InceptionV3
# from keras.applications.vgg16 import VGG16
# from keras.applications.resnet50 import ResNet50

# %%
data = h5py.File("./data_sample.hdf5", "r")
print("data keys: " + str(list(data.keys())))
# Out:
# data keys: ['images', 'labels', 'observation_days']

# %%
images = data["images"][:]
print("image shape: (sample, x_size, y_size, epoch) = " + str(images.shape))
labels = data["labels"][:]
# Out:
# image shape: (sample, x_size, y_size, epoch) = (72000, 21, 21, 48)

# %%
def scale_images(images):
    t_images = np.transpose(images, (0,3,1,2))
    rt_images = t_images.reshape(72000*48, 21, 21)
    max_per_img = np.max(rt_images.reshape(-1, 21*21), axis=1, keepdims=1)
    scaled_images = rt_images.reshape(-1, 21*21) / max_per_img
    scaled_images = scaled_images.reshape(-1, 21, 21).reshape(-1, 48, 21, 21)
    return scaled_images

# %%
def txt2digit(labels):
    dic = {'Asteroids':0, 'Constant':1, 'EmptyLigh':2, 'M33Cephei':3, 'RRLyrae':4, 'Supernova':5}
    labels_digit = np.array([dic[i] for i in labels])
    return labels_digit

# %%
def build_dataset(images, labels, seq2seq=False):
    
    train_indices = np.random.choice(np.arange(images.shape[0]), int( 0.7 * images.shape[0]))
    val_indices = list(set(np.arange(images.shape[0])) - set(train_indices))
    
    x = np.transpose(images, (0, 3, 1, 2))
    x = np.expand_dims(x, len(x.shape))
    y = to_categorical(txt2digit(labels))
    
    if seq2seq:
        y = np.repeat(y, 48).reshape(-1, 48, 6)
    
    return x, y

# %%
x, y = build_dataset(images, labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=209, stratify=y)

# %%
x_train.shape
# Out:
# (57600, 48, 21, 21, 1)

# %%
def init_model3(cnn_input_dim=21, cnn_output_dim=128, cnn_dropout=0.5,
               rnn_hidden_dim=128, rnn_output_dim=64, num_classes=6, rnn_dropout=0.5, timestep=48,
               bidir_mode='concat'):
    
    input_shape = (timestep, cnn_input_dim, cnn_input_dim, 1, )
    
    model = Sequential()
    
    model.add(TimeDistributed(Conv2D(48, (4,4), \
                     padding='same', activation='relu', kernel_initializer='uniform'), input_shape=input_shape))
#     model.add(TimeDistributed(BatchNormalization()))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))
    
    model.add(TimeDistributed(Conv2D(24, (3,3), padding='same', activation='relu', kernel_initializer='uniform')))
#     model.add(TimeDistributed(BatchNormalization()))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))

    model.add(TimeDistributed(Conv2D(12, (3,3), padding='same', activation='relu', kernel_initializer='uniform')))
    model.add(TimeDistributed(BatchNormalization(momentum=0.3)))
#     model.add(BatchNormalization(momentum=0.4))
    model.add(TimeDistributed(MaxPooling2D((3,3), strides=(1,1))))
    
    model.add(TimeDistributed(Flatten()))

    model.add(TimeDistributed(Dense(128, activation='relu')))
    model.add(Dropout(0.25))
    
    model.add(LSTM(rnn_hidden_dim, dropout=rnn_dropout, return_sequences=True))
    model.add(LSTM(rnn_hidden_dim, dropout=rnn_dropout))
    
    model.add(Dense(6, activation='softmax'))
    
    return model

# %%
opt = keras.optimizers.Adam(lr=5*1e-4)
# model3 = init_model3(bidir_mode='ave')
model3 = keras.models.load_model('saved_models/batchnorm_best.hdf5')
model3.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_71 (TimeDis (None, 48, 21, 21, 48)    816
# _________________________________________________________________
# time_distributed_72 (TimeDis (None, 48, 19, 19, 48)    0
# _________________________________________________________________
# time_distributed_73 (TimeDis (None, 48, 19, 19, 24)    10392
# _________________________________________________________________
# time_distributed_74 (TimeDis (None, 48, 17, 17, 24)    0
# _________________________________________________________________
# time_distributed_75 (TimeDis (None, 48, 17, 17, 12)    2604
# _________________________________________________________________
# time_distributed_76 (TimeDis (None, 48, 17, 17, 12)    48
# _________________________________________________________________
# time_distributed_77 (TimeDis (None, 48, 15, 15, 12)    0
# _________________________________________________________________
# time_distributed_78 (TimeDis (None, 48, 2700)          0
# _________________________________________________________________
# time_distributed_79 (TimeDis (None, 48, 128)           345728
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 48, 128)           0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 48, 128)           131584
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 623,530
# Trainable params: 623,506
# Non-trainable params: 24
# _________________________________________________________________

# %%
batch_size = 100
epochs = 100

checkpoint = keras.callbacks.ModelCheckpoint('batchnorm_best.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')
model3_fit = model3.fit(x_train[::4], y_train[::4],
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              callbacks=[checkpoint],
              shuffle=True)
# Out:
# Train on 14400 samples, validate on 14400 samples
# Epoch 1/100
# 14400/14400 [==============================] - 108s 8ms/step - loss: 0.4617 - acc: 0.7890 - val_loss: 0.4955 - val_acc: 0.7965
#
# Epoch 00001: val_acc improved from -inf to 0.79646, saving model to batchnorm_best.hdf5
# Epoch 2/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4575 - acc: 0.7933 - val_loss: 0.4140 - val_acc: 0.8216
#
# Epoch 00002: val_acc improved from 0.79646 to 0.82160, saving model to batchnorm_best.hdf5
# Epoch 3/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4557 - acc: 0.7985 - val_loss: 0.4678 - val_acc: 0.7897
#
# Epoch 00003: val_acc did not improve from 0.82160
# Epoch 4/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4554 - acc: 0.7948 - val_loss: 0.4593 - val_acc: 0.8032
#
# Epoch 00004: val_acc did not improve from 0.82160
# Epoch 5/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4568 - acc: 0.7930 - val_loss: 0.4297 - val_acc: 0.8180
#
# Epoch 00005: val_acc did not improve from 0.82160
# Epoch 6/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4464 - acc: 0.8019 - val_loss: 0.4329 - val_acc: 0.8181
#
# Epoch 00006: val_acc did not improve from 0.82160
# Epoch 7/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4560 - acc: 0.7983 - val_loss: 0.4109 - val_acc: 0.8305
#
# Epoch 00007: val_acc improved from 0.82160 to 0.83049, saving model to batchnorm_best.hdf5
# Epoch 8/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4437 - acc: 0.8013 - val_loss: 0.4370 - val_acc: 0.8201
#
# Epoch 00008: val_acc did not improve from 0.83049
# Epoch 9/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4537 - acc: 0.7982 - val_loss: 0.4584 - val_acc: 0.8021
#
# Epoch 00009: val_acc did not improve from 0.83049
# Epoch 10/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.4392 - acc: 0.8062 - val_loss: 0.4042 - val_acc: 0.8314
#
# Epoch 00010: val_acc improved from 0.83049 to 0.83139, saving model to batchnorm_best.hdf5
# Epoch 11/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4325 - acc: 0.8098 - val_loss: 0.4684 - val_acc: 0.8092
#
# Epoch 00011: val_acc did not improve from 0.83139
# Epoch 12/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4482 - acc: 0.7983 - val_loss: 0.4239 - val_acc: 0.8260
#
# Epoch 00012: val_acc did not improve from 0.83139
# Epoch 13/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4315 - acc: 0.8143 - val_loss: 0.3832 - val_acc: 0.8406
#
# Epoch 00013: val_acc improved from 0.83139 to 0.84056, saving model to batchnorm_best.hdf5
# Epoch 14/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4238 - acc: 0.8112 - val_loss: 0.3873 - val_acc: 0.8424
#
# Epoch 00014: val_acc improved from 0.84056 to 0.84243, saving model to batchnorm_best.hdf5
# Epoch 15/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4180 - acc: 0.8194 - val_loss: 0.4051 - val_acc: 0.8328
#
# Epoch 00015: val_acc did not improve from 0.84243
# Epoch 16/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4188 - acc: 0.8183 - val_loss: 0.4022 - val_acc: 0.8361
#
# Epoch 00016: val_acc did not improve from 0.84243
# Epoch 17/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4713 - acc: 0.7976 - val_loss: 0.4233 - val_acc: 0.8198
#
# Epoch 00017: val_acc did not improve from 0.84243
# Epoch 18/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4289 - acc: 0.8092 - val_loss: 0.4080 - val_acc: 0.8381
#
# Epoch 00018: val_acc did not improve from 0.84243
# Epoch 19/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4154 - acc: 0.8215 - val_loss: 0.3817 - val_acc: 0.8449
#
# Epoch 00019: val_acc improved from 0.84243 to 0.84493, saving model to batchnorm_best.hdf5
# Epoch 20/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.4205 - acc: 0.8170 - val_loss: 0.4234 - val_acc: 0.8234
#
# Epoch 00020: val_acc did not improve from 0.84493
# Epoch 21/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.4172 - acc: 0.8199 - val_loss: 0.3887 - val_acc: 0.8416
#
# Epoch 00021: val_acc did not improve from 0.84493
# Epoch 22/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.4004 - acc: 0.8281 - val_loss: 0.4159 - val_acc: 0.8338
#
# Epoch 00022: val_acc did not improve from 0.84493
# Epoch 23/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4134 - acc: 0.8173 - val_loss: 0.3839 - val_acc: 0.8437
#
# Epoch 00023: val_acc did not improve from 0.84493
# Epoch 24/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.4134 - acc: 0.8224 - val_loss: 0.3682 - val_acc: 0.8532
#
# Epoch 00024: val_acc improved from 0.84493 to 0.85319, saving model to batchnorm_best.hdf5
# Epoch 25/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.4012 - acc: 0.8299 - val_loss: 0.3638 - val_acc: 0.8562
#
# Epoch 00025: val_acc improved from 0.85319 to 0.85625, saving model to batchnorm_best.hdf5
# Epoch 26/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3911 - acc: 0.8342 - val_loss: 0.3573 - val_acc: 0.8601
#
# Epoch 00026: val_acc improved from 0.85625 to 0.86014, saving model to batchnorm_best.hdf5
# Epoch 27/100
# 14400/14400 [==============================] - 105s 7ms/step - loss: 0.3898 - acc: 0.8307 - val_loss: 0.4212 - val_acc: 0.8338
#
# Epoch 00027: val_acc did not improve from 0.86014
# Epoch 28/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3919 - acc: 0.8326 - val_loss: 0.3576 - val_acc: 0.8553
#
# Epoch 00028: val_acc did not improve from 0.86014
# Epoch 29/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3960 - acc: 0.8323 - val_loss: 0.3717 - val_acc: 0.8542
#
# Epoch 00029: val_acc did not improve from 0.86014
# Epoch 30/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3884 - acc: 0.8330 - val_loss: 0.3477 - val_acc: 0.8576
#
# Epoch 00030: val_acc did not improve from 0.86014
# Epoch 31/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3876 - acc: 0.8343 - val_loss: 0.3939 - val_acc: 0.8447
#
# Epoch 00031: val_acc did not improve from 0.86014
# Epoch 32/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3854 - acc: 0.8374 - val_loss: 0.3657 - val_acc: 0.8572
#
# Epoch 00032: val_acc did not improve from 0.86014
# Epoch 33/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3755 - acc: 0.8419 - val_loss: 0.3453 - val_acc: 0.8624
#
# Epoch 00033: val_acc improved from 0.86014 to 0.86236, saving model to batchnorm_best.hdf5
# Epoch 34/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3878 - acc: 0.8349 - val_loss: 0.3380 - val_acc: 0.8656
#
# Epoch 00034: val_acc improved from 0.86236 to 0.86563, saving model to batchnorm_best.hdf5
# Epoch 35/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3702 - acc: 0.8401 - val_loss: 0.3421 - val_acc: 0.8625
#
# Epoch 00035: val_acc did not improve from 0.86563
# Epoch 36/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3574 - acc: 0.8504 - val_loss: 0.3509 - val_acc: 0.8642
#
# Epoch 00036: val_acc did not improve from 0.86563
# Epoch 37/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3694 - acc: 0.8447 - val_loss: 0.4134 - val_acc: 0.8452
#
# Epoch 00037: val_acc did not improve from 0.86563
# Epoch 38/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3722 - acc: 0.8415 - val_loss: 0.3201 - val_acc: 0.8710
#
# Epoch 00038: val_acc improved from 0.86563 to 0.87097, saving model to batchnorm_best.hdf5
# Epoch 39/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3619 - acc: 0.8469 - val_loss: 0.3321 - val_acc: 0.8706
#
# Epoch 00039: val_acc did not improve from 0.87097
# Epoch 40/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3556 - acc: 0.8487 - val_loss: 0.3733 - val_acc: 0.8556
#
# Epoch 00040: val_acc did not improve from 0.87097
# Epoch 41/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3568 - acc: 0.8503 - val_loss: 0.3528 - val_acc: 0.8631
#
# Epoch 00041: val_acc did not improve from 0.87097
# Epoch 42/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3510 - acc: 0.8533 - val_loss: 0.3675 - val_acc: 0.8529
#
# Epoch 00042: val_acc did not improve from 0.87097
# Epoch 43/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3502 - acc: 0.8524 - val_loss: 0.3113 - val_acc: 0.8798
#
# Epoch 00043: val_acc improved from 0.87097 to 0.87979, saving model to batchnorm_best.hdf5
# Epoch 44/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3523 - acc: 0.8535 - val_loss: 0.3242 - val_acc: 0.8733
#
# Epoch 00044: val_acc did not improve from 0.87979
# Epoch 45/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3465 - acc: 0.8558 - val_loss: 0.3414 - val_acc: 0.8715
#
# Epoch 00045: val_acc did not improve from 0.87979
# Epoch 46/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3787 - acc: 0.8404 - val_loss: 0.3642 - val_acc: 0.8592
#
# Epoch 00046: val_acc did not improve from 0.87979
# Epoch 47/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3646 - acc: 0.8492 - val_loss: 0.3089 - val_acc: 0.8782
#
# Epoch 00047: val_acc did not improve from 0.87979
# Epoch 48/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3423 - acc: 0.8544 - val_loss: 0.3174 - val_acc: 0.8741
#
# Epoch 00048: val_acc did not improve from 0.87979
# Epoch 49/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3433 - acc: 0.8556 - val_loss: 0.3543 - val_acc: 0.8675
#
# Epoch 00049: val_acc did not improve from 0.87979
# Epoch 50/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3358 - acc: 0.8601 - val_loss: 0.3150 - val_acc: 0.8744
#
# Epoch 00050: val_acc did not improve from 0.87979
# Epoch 51/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3442 - acc: 0.8564 - val_loss: 0.3241 - val_acc: 0.8764
#
# Epoch 00051: val_acc did not improve from 0.87979
# Epoch 52/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3418 - acc: 0.8572 - val_loss: 0.3307 - val_acc: 0.8657
#
# Epoch 00052: val_acc did not improve from 0.87979
# Epoch 53/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3426 - acc: 0.8563 - val_loss: 0.3499 - val_acc: 0.8678
#
# Epoch 00053: val_acc did not improve from 0.87979
# Epoch 54/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3252 - acc: 0.8627 - val_loss: 0.2962 - val_acc: 0.8857
#
# Epoch 00054: val_acc improved from 0.87979 to 0.88569, saving model to batchnorm_best.hdf5
# Epoch 55/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3278 - acc: 0.8636 - val_loss: 0.3172 - val_acc: 0.8801
#
# Epoch 00055: val_acc did not improve from 0.88569
# Epoch 56/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3231 - acc: 0.8658 - val_loss: 0.2913 - val_acc: 0.8876
#
# Epoch 00056: val_acc improved from 0.88569 to 0.88757, saving model to batchnorm_best.hdf5
# Epoch 57/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3309 - acc: 0.8610 - val_loss: 0.3065 - val_acc: 0.8824
#
# Epoch 00057: val_acc did not improve from 0.88757
# Epoch 58/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3315 - acc: 0.8632 - val_loss: 0.3154 - val_acc: 0.8790
#
# Epoch 00058: val_acc did not improve from 0.88757
# Epoch 59/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3273 - acc: 0.8640 - val_loss: 0.2935 - val_acc: 0.8882
#
# Epoch 00059: val_acc improved from 0.88757 to 0.88819, saving model to batchnorm_best.hdf5
# Epoch 60/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3510 - acc: 0.8556 - val_loss: 0.2937 - val_acc: 0.8876
#
# Epoch 00060: val_acc did not improve from 0.88819
# Epoch 61/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3198 - acc: 0.8682 - val_loss: 0.3347 - val_acc: 0.8760
#
# Epoch 00061: val_acc did not improve from 0.88819
# Epoch 62/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3361 - acc: 0.8600 - val_loss: 0.3035 - val_acc: 0.8842
#
# Epoch 00062: val_acc did not improve from 0.88819
# Epoch 63/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3182 - acc: 0.8661 - val_loss: 0.2834 - val_acc: 0.8919
#
# Epoch 00063: val_acc improved from 0.88819 to 0.89194, saving model to batchnorm_best.hdf5
# Epoch 64/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3214 - acc: 0.8649 - val_loss: 0.3215 - val_acc: 0.8785
#
# Epoch 00064: val_acc did not improve from 0.89194
# Epoch 65/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3047 - acc: 0.8747 - val_loss: 0.2908 - val_acc: 0.8897
#
# Epoch 00065: val_acc did not improve from 0.89194
# Epoch 66/100
# 14400/14400 [==============================] - 105s 7ms/step - loss: 0.3170 - acc: 0.8680 - val_loss: 0.2954 - val_acc: 0.8851
#
# Epoch 00066: val_acc did not improve from 0.89194
# Epoch 67/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3160 - acc: 0.8684 - val_loss: 0.2896 - val_acc: 0.8867
#
# Epoch 00067: val_acc did not improve from 0.89194
# Epoch 68/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3111 - acc: 0.8709 - val_loss: 0.3065 - val_acc: 0.8812
#
# Epoch 00068: val_acc did not improve from 0.89194
# Epoch 69/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3145 - acc: 0.8705 - val_loss: 0.2753 - val_acc: 0.8938
#
# Epoch 00069: val_acc improved from 0.89194 to 0.89382, saving model to batchnorm_best.hdf5
# Epoch 70/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3073 - acc: 0.8737 - val_loss: 0.2853 - val_acc: 0.8962
#
# Epoch 00070: val_acc improved from 0.89382 to 0.89618, saving model to batchnorm_best.hdf5
# Epoch 71/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3099 - acc: 0.8744 - val_loss: 0.2733 - val_acc: 0.8958
#
# Epoch 00071: val_acc did not improve from 0.89618
# Epoch 72/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.3042 - acc: 0.8723 - val_loss: 0.2861 - val_acc: 0.8940
#
# Epoch 00072: val_acc did not improve from 0.89618
# Epoch 73/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2924 - acc: 0.8806 - val_loss: 0.3185 - val_acc: 0.8834
#
# Epoch 00073: val_acc did not improve from 0.89618
# Epoch 74/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2945 - acc: 0.8776 - val_loss: 0.2918 - val_acc: 0.8893
#
# Epoch 00074: val_acc did not improve from 0.89618
# Epoch 75/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2944 - acc: 0.8774 - val_loss: 0.3060 - val_acc: 0.8862
#
# Epoch 00075: val_acc did not improve from 0.89618
# Epoch 76/100
# 14400/14400 [==============================] - 105s 7ms/step - loss: 0.3057 - acc: 0.8742 - val_loss: 0.2915 - val_acc: 0.8908
#
# Epoch 00076: val_acc did not improve from 0.89618
# Epoch 77/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2996 - acc: 0.8769 - val_loss: 2.4111 - val_acc: 0.4892
#
# Epoch 00077: val_acc did not improve from 0.89618
# Epoch 78/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3896 - acc: 0.8443 - val_loss: 0.3008 - val_acc: 0.8874
#
# Epoch 00078: val_acc did not improve from 0.89618
# Epoch 79/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3161 - acc: 0.8692 - val_loss: 0.2653 - val_acc: 0.8978
#
# Epoch 00079: val_acc improved from 0.89618 to 0.89778, saving model to batchnorm_best.hdf5
# Epoch 80/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3093 - acc: 0.8744 - val_loss: 0.2922 - val_acc: 0.8944
#
# Epoch 00080: val_acc did not improve from 0.89778
# Epoch 81/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.3020 - acc: 0.8748 - val_loss: 0.2762 - val_acc: 0.8976
#
# Epoch 00081: val_acc did not improve from 0.89778
# Epoch 82/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2949 - acc: 0.8772 - val_loss: 0.2690 - val_acc: 0.8984
#
# Epoch 00082: val_acc improved from 0.89778 to 0.89840, saving model to batchnorm_best.hdf5
# Epoch 83/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2961 - acc: 0.8768 - val_loss: 0.2651 - val_acc: 0.8988
#
# Epoch 00083: val_acc improved from 0.89840 to 0.89882, saving model to batchnorm_best.hdf5
# Epoch 84/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2852 - acc: 0.8824 - val_loss: 0.3256 - val_acc: 0.8767
#
# Epoch 00084: val_acc did not improve from 0.89882
# Epoch 85/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2926 - acc: 0.8806 - val_loss: 0.2835 - val_acc: 0.8938
#
# Epoch 00085: val_acc did not improve from 0.89882
# Epoch 86/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2842 - acc: 0.8828 - val_loss: 0.2891 - val_acc: 0.8908
#
# Epoch 00086: val_acc did not improve from 0.89882
# Epoch 87/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2909 - acc: 0.8816 - val_loss: 0.3032 - val_acc: 0.8897
#
# Epoch 00087: val_acc did not improve from 0.89882
# Epoch 88/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2857 - acc: 0.8839 - val_loss: 0.2785 - val_acc: 0.8972
#
# Epoch 00088: val_acc did not improve from 0.89882
# Epoch 89/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2856 - acc: 0.8857 - val_loss: 0.2763 - val_acc: 0.8899
#
# Epoch 00089: val_acc did not improve from 0.89882
# Epoch 90/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2799 - acc: 0.8847 - val_loss: 0.2838 - val_acc: 0.8973
#
# Epoch 00090: val_acc did not improve from 0.89882
# Epoch 91/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2808 - acc: 0.8870 - val_loss: 0.3047 - val_acc: 0.8863
#
# Epoch 00091: val_acc did not improve from 0.89882
# Epoch 92/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2761 - acc: 0.8862 - val_loss: 0.2656 - val_acc: 0.8998
#
# Epoch 00092: val_acc improved from 0.89882 to 0.89979, saving model to batchnorm_best.hdf5
# Epoch 93/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2756 - acc: 0.8867 - val_loss: 0.2815 - val_acc: 0.8936
#
# Epoch 00093: val_acc did not improve from 0.89979
# Epoch 94/100
# 14400/14400 [==============================] - 107s 7ms/step - loss: 0.2818 - acc: 0.8847 - val_loss: 0.2744 - val_acc: 0.8990
#
# Epoch 00094: val_acc did not improve from 0.89979
# Epoch 95/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2757 - acc: 0.8865 - val_loss: 0.2856 - val_acc: 0.8872
#
# Epoch 00095: val_acc did not improve from 0.89979
# Epoch 96/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2695 - acc: 0.8900 - val_loss: 0.2818 - val_acc: 0.9003
#
# Epoch 00096: val_acc improved from 0.89979 to 0.90035, saving model to batchnorm_best.hdf5
# Epoch 97/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2757 - acc: 0.8878 - val_loss: 0.2843 - val_acc: 0.8980
#
# Epoch 00097: val_acc did not improve from 0.90035
# Epoch 98/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2802 - acc: 0.8882 - val_loss: 0.2697 - val_acc: 0.9047
#
# Epoch 00098: val_acc improved from 0.90035 to 0.90472, saving model to batchnorm_best.hdf5
# Epoch 99/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2692 - acc: 0.8892 - val_loss: 0.2635 - val_acc: 0.9019
#
# Epoch 00099: val_acc did not improve from 0.90472
# Epoch 100/100
# 14400/14400 [==============================] - 106s 7ms/step - loss: 0.2700 - acc: 0.8924 - val_loss: 0.2843 - val_acc: 0.8939
#
# Epoch 00100: val_acc did not improve from 0.90472

# %%
with open('saved_history/batch_norm/batch_norm_history_1.json', 'w') as f:
    json.dump(model3_fit.history, f)

# %%
with open('saved_history/batch_norm/batch_norm_history.json', 'r') as f:
    hist_ep100 = json.load(f)
with open('saved_history/batch_norm/batch_norm_history_1.json', 'r') as f:
    hist_ep200 = json.load(f)

# %%
plt.figure(figsize=(8,8 ))
plt.plot(range(len(hist_ep100['acc']+hist_ep200['acc'])),\
         hist_ep100['acc']+hist_ep200['acc'], label='Training set accuracy')
plt.plot(range(len(hist_ep100['acc']+hist_ep200['acc'])), \
         hist_ep100['val_acc']+hist_ep200['val_acc'], label='Testing set accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Load saved best model and visualize the confusion matrix

# %%
model = keras.models.load_model('saved_models/rcnn_simple_lstm_ep300.hdf5')

# %%
def compute_confusion_matrix(model, x, y):
    from sklearn.metrics import confusion_matrix
    pred = model.predict_classes(x)
    labels = y @ np.array([0,1,2,3,4,5]).T
    cm = confusion_matrix(labels, pred)
    return cm

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    plt.figure(figsize=(6,6))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    tick_marks = np.arange(len(classes))
    plt.grid(False)
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = compute_confusion_matrix(model, x_test, y_test)
plot_confusion_matrix(cm, classes=['Asteroids', 'Constant', 'EmptyLigh', 'M33Cephei', 'RRLyrae', 'Supernova'])
# Out:
# Confusion matrix, without normalization
